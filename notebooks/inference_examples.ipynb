# %%
# notebooks/inference_examples.ipynb

{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Exemplos de Inferência com Neve Cascade 90M"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "from src.model import NeveCascadeModel\n",
    "model = NeveCascadeModel.load_from_checkpoint('../checkpoints/neve_cascade_90m.pt')\n",
    "print(model.generate('Explique o conceito de overfitting.'))"
   ]
  }
 ],
 "metadata": {},
 "nbformat": 4,
 "nbformat_minor": 2
}
